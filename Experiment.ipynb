# %%
import numpy as np
import cv2
import torch
from ultralytics import YOLO
import cvzone
import math
from sort.sort import *

# %%
model = YOLO("yolov8l.pt")

# %%
class_names = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat", "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat", "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella", "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat", "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup", "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli", "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed" "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone", "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors", "teddy bear", "hair drier","toothbrush"]

# %%
# Initialize video capture
cap = cv2.VideoCapture(r"C:\Users\49179\Desktop\Projects\Computer_vision_data\cars.mp4")
cap.set(3, 1080)
cap.set(4, 720)

# Initialize the SORT tracker
tracker = Sort(max_age=20, min_hits=3, iou_threshold=0.3)
limits = [100, 450, 450, 450]
totalCount = []

while True:
    ret, frame = cap.read()
    
    if not ret:
        break  # Break the loop if no frame is returned (end of video)
    
    # Flip and resize the frame
    flipped = cv2.resize(frame, (720, 720))
    ht, wt = flipped.shape[0:2]
    
    # Create a mask
    image = np.zeros_like(flipped)
    region = np.array([[(220, 250), (150, 450), (350, 450), (350, 250)]], np.int32)
    cv2.fillPoly(image, region, color=(255, 255, 255))
    masked_img = cv2.bitwise_and(flipped, image)

    # Process the frame with the model
    results = model(masked_img, stream=True)
    detections = np.empty((0, 5))
    
    for r in results:
        boxes = r.boxes
        for box in boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            w, h = x2 - x1, y2 - y1

            # Calculate confidence
            confidence = box.conf[0].item()
            confidence = math.ceil(confidence * 100) / 100

            # Get the class
            cls = int(box.cls[0])
            
            # Filter detections by class and confidence
            if (class_names[cls] in ["car", "truck", "bus", "motorbike"]) and confidence > 0.3:
                cvzone.putTextRect(flipped, f'{class_names[cls]} {confidence}', (max(0, x1), max(40, y1)), scale=0.6, thickness=1, offset=3)
                cvzone.cornerRect(flipped, (x1, y1, w, h), l=9)
                new_array = np.array([x1, y1, x2, y2, confidence])
                detections = np.vstack((detections, new_array))

    # Update tracker with the detections
    track_results = tracker.update(detections)
    cv2.line(flipped, (limits[0], limits[1]), (limits[2], limits[3]), (0, 0, 255), 5)
    
    # Draw the tracked objects
    for result in track_results:
        x1, y1, x2, y2, track_id = map(int, result)
        cv2.rectangle(flipped, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cvzone.putTextRect(flipped, f'ID: {track_id}', (x1, y1 - 10), scale=0.6, thickness=1, offset=3)

        cx, cy = (x1 + x2) // 2, (y1 + y2) // 2
        cv2.circle(flipped, (cx, cy), 5, (255, 0, 255), cv2.FILLED)

        print(f"Object ID: {track_id}, Center: ({cx}, {cy})")  # Debug print to track IDs and positions
 
        if limits[0] < cx < limits[2] and limits[1] - 15 < cy < limits[1] + 15:
            if track_id not in totalCount:
                totalCount.append(track_id)
                cv2.line(flipped, (limits[0], limits[1]), (limits[2], limits[3]), (0, 255, 0), 5)
                print(f"Counted ID: {track_id}, Total Count: {len(totalCount)}")  # Debug print for counting

    cvzone.putTextRect(flipped, f'Count: {len(totalCount)}', (50, 50))
    cv2.putText(flipped, str(len(totalCount)), (255, 100), cv2.FONT_HERSHEY_PLAIN, 5, (50, 50, 255), 8)

    # Display the frame
    cv2.imshow('Frame', flipped)
    
    # Break the loop if 'q' is pressed
    if cv2.waitKey(70) & 0xFF == ord('q'):
        break

# Release the capture and destroy all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x640 3 cars, 366.1ms
# Speed: 7.0ms preprocess, 366.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 433, Center: (335, 372)
# Object ID: 432, Center: (271, 259)
# Object ID: 431, Center: (245, 399)
#
# 0: 640x640 3 cars, 52.8ms
# Speed: 4.0ms preprocess, 52.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID:
 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 442, Center: (333, 352)
# Object ID: 437, Center: (293, 334)
# Object ID: 436, Center: (213, 344)
#
# 0: 640x640 3 cars, 1 bus, 2 trucks, 43.6ms
# Speed: 3.0ms preprocess, 43.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 442, Center: (330, 379)
# Object ID: 437, Center: (287, 353)
# Object ID: 436, Center: (201, 364)
#
# 0: 640x640 2 cars, 1 bus, 1 truck, 43.9ms
# Speed: 3.0ms preprocess, 43.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 437, Center: (279, 375)
#
# 0: 640x640 2 cars, 2 trucks, 43.7ms
# Speed: 3.2ms preprocess, 43.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 445, Center: (175, 413)
# Object ID: 437, Center: (270, 400)
# Object ID: 435, Center: (322, 405)
#
# 0: 640x640 3 cars, 43.0ms
# Speed: 4.0ms preprocess, 43.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 446, Center: (300, 272)
# Object ID: 445, Center: (165, 428)
# Object ID: 437, Center: (260, 417)
#
# 0: 640x640 2 cars, 43.7ms
# Speed: 3.0ms preprocess, 43.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 446, Center: (296, 279)
# Object ID: 437, Center: (251, 433)
#
# 0: 640x640 1 car, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 446, Center: (292, 289)
#
# 0: 640x640 1 car, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 446, Center: (287, 302)
#
# 0: 640x640 2 cars, 43.5ms
# Speed: 3.0ms preprocess, 43.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 446, Center: (281, 317)
#
# 0: 640x640 2 cars, 43.2ms
# Speed: 4.0ms preprocess, 43.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 446, Center: (275, 333)
#
# 0: 640x640 2 cars, 44.5ms
# Speed: 3.0ms preprocess, 44.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 446, Center: (268, 350)
# Object ID: 438, Center: (269, 262)
#
# 0: 640x640 2 cars, 43.6ms
# Speed: 3.2ms preprocess, 43.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 446, Center: (260, 371)
# Object ID: 438, Center: (264, 267)
#
# 0: 640x640 2 cars, 43.2ms
# Speed: 4.3ms preprocess, 43.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 446, Center: (250, 394)
# Object ID: 438, Center: (259, 275)
#
# 0: 640x640 2 cars, 43.7ms
# Speed: 3.4ms preprocess, 43.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 446, Center: (239, 410)
# Object ID: 438, Center: (252, 285)
#
# 0: 640x640 2 cars, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 446, Center: (228, 425)
# Object ID: 438, Center: (244, 298)
#
# 0: 640x640 1 car, 43.5ms
# Speed: 3.0ms preprocess, 43.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 438, Center: (235, 312)
#
# 0: 640x640 1 car, 43.5ms
# Speed: 3.0ms preprocess, 43.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 438, Center: (226, 327)
#
# 0: 640x640 1 car, 43.6ms
# Speed: 3.0ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 438, Center: (214, 345)
#
# 0: 640x640 1 car, 43.7ms
# Speed: 3.0ms preprocess, 43.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 438, Center: (202, 365)
#
# 0: 640x640 2 cars, 1 truck, 43.5ms
# Speed: 3.2ms preprocess, 43.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 438, Center: (187, 389)
#
# 0: 640x640 2 cars, 43.5ms
# Speed: 3.0ms preprocess, 43.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 438, Center: (176, 409)
#
# 0: 640x640 2 cars, 44.5ms
# Speed: 3.0ms preprocess, 44.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 car, 44.1ms
# Speed: 2.9ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 448, Center: (336, 322)
#
# 0: 640x640 1 car, 43.8ms
# Speed: 3.0ms preprocess, 43.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 448, Center: (333, 345)
#
# 0: 640x640 1 car, 44.7ms
# Speed: 3.0ms preprocess, 44.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 448, Center: (331, 371)
#
# 0: 640x640 1 car, 1 airplane, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 448, Center: (326, 397)
#
# 0: 640x640 1 car, 1 airplane, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 airplane, 44.2ms
# Speed: 4.0ms preprocess, 44.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 44.2ms
# Speed: 4.3ms preprocess, 44.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 car, 43.0ms
# Speed: 3.0ms preprocess, 43.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 car, 43.5ms
# Speed: 3.0ms preprocess, 43.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 cars, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2
44.0ms
# Speed: 4.0ms preprocess, 44.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 459, Center: (330, 363)
# Object ID: 457, Center: (243, 310)
# Object ID: 456, Center: (271, 407)
#
# 0: 640x640 3 cars, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 463, Center: (327, 390)
# Object ID: 457, Center: (237, 322)
# Object ID: 456, Center: (260, 426)
#
# 0: 640x640 4 cars, 43.5ms
# Speed: 3.0ms preprocess, 43.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 463, Center: (323, 406)
# Object ID: 457, Center: (229, 334)
#
# 0: 640x640 3 cars, 44.3ms
# Speed: 2.2ms preprocess, 44.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 463, Center: (316, 422)
# Object ID: 457, Center: (221, 349)
#
# 0: 640x640 3 cars, 43.7ms
# Speed: 3.0ms preprocess, 43.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 457, Center: (211, 365)
#
# 0: 640x640 2 cars, 44.3ms
# Speed: 3.0ms preprocess, 44.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 464, Center: (309, 272)
# Object ID: 457, Center: (201, 384)
#
# 0: 640x640 1 car, 1 truck, 44.0ms
# Speed: 3.2ms preprocess, 44.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 464, Center: (305, 282)
# Object ID: 457, Center: (188, 403)
#
# 0: 640x640 2 cars, 1 truck, 44.1ms
# Speed: 3.4ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 464, Center: (301, 294)
# Object ID: 457, Center: (178, 416)
#
# 0: 640x640 3 cars, 43.0ms
# Speed: 4.0ms preprocess, 43.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 464, Center: (295, 306)
#
# 0: 640x640 2 cars, 44.1ms
# Speed: 3.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 464, Center: (289, 322)
#
# 0: 640x640 2 cars, 43.9ms
# Speed: 3.0ms preprocess, 43.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 464, Center: (282, 339)
#
# 0: 640x640 2 cars, 43.9ms
# Speed: 3.1ms preprocess, 43.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 467, Center: (334, 401)
# Object ID: 464, Center: (274, 358)
#
# 0: 640x640 3 cars, 43.0ms
# Speed: 4.0ms preprocess, 43.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 467, Center: (329, 419)
# Object ID: 464, Center: (264, 380)
#
# 0: 640x640 3 cars, 1 truck, 43.4ms
# Speed: 3.7ms preprocess, 43.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 464, Center: (253, 404)
#
# 0: 640x640 4 cars, 1 truck, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 1 truck, 43.8ms
# Speed: 3.0ms preprocess, 43.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 468, Center: (281, 261)
#
# 0: 640x640 3 cars, 1 truck, 43.6ms
# Speed: 3.0ms preprocess, 43.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 469, Center: (313, 269)
# Object ID: 468, Center: (278, 264)
#
# 0: 640x640 2 cars, 1 truck, 44.0ms
# Speed: 4.0ms preprocess, 44.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 470, Center: (338, 319)
# Object ID: 469, Center: (309, 278)
#
# 0: 640x640 2 cars, 1 truck, 44.0ms
# Speed: 4.0ms preprocess, 44.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 471, Center: (271, 272)
# Object ID: 470, Center: (336, 338)
# Object ID: 469, Center: (304, 290)
#
# 0: 640x640 3 cars, 43.0ms
# Speed: 3.0ms preprocess, 43.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 471, Center: (267, 274)
# Object ID: 470, Center: (332, 360)
# Object ID: 469, Center: (298, 302)
#
# 0: 640x640 3 cars, 1 truck, 43.9ms
# Speed: 3.0ms preprocess, 43.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 471, Center: (263, 279)
# Object ID: 470, Center: (329, 386)
# Object ID: 469, Center: (292, 316)
#
# 0: 640x640 3 cars, 1 truck, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 471, Center: (259, 285)
# Object ID: 470, Center: (325, 410)
# Object ID: 469, Center: (285, 333)
#
# 0: 640x640 4 cars, 43.1ms
# Speed: 3.7ms preprocess, 43.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 471, Center: (253, 292)
# Object ID: 469, Center: (278, 350)
#
# 0: 640x640 3 cars, 1 truck, 43.4ms
# Speed: 3.7ms preprocess, 43.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 471, Center: (248, 302)
# Object ID: 469, Center: (269, 372)
#
# 0: 640x640 2 cars, 1 truck, 44.0ms
# Speed: 4.0ms preprocess, 44.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 473, Center: (333, 408)
# Object ID: 471, Center: (242, 312)
# Object ID: 469, Center: (259, 397)
#
# 0: 640x640 3 cars, 1 truck, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 471, Center: (236, 321)
#
# 0: 640x640 2 cars, 44.5ms
# Speed: 3.0ms preprocess, 44.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 471, Center: (228, 333)
#
# 0: 640x640 2 cars, 1 truck, 44.4ms
# Speed: 3.0ms preprocess, 44.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 471, Center: (220, 345)
#
# 0: 640x640 2 cars, 1 truck, 44.0ms
# Speed: 4.0ms preprocess, 44.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 471, Center: (212, 359)
#
# 0: 640x640 1 car, 1 truck, 44.0ms
# Speed: 4.6ms preprocess, 44.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 471, Center: (202, 374)
#
# 0: 640x640 1 car, 1 truck, 43.6ms
# Speed: 3.0ms preprocess, 43.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 474, Center: (336, 389)
# Object ID: 471, Center: (190, 391)
#
# 0: 640x640 1 car, 1 truck, 45.0ms
# Speed: 3.0ms preprocess, 45.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 474, Center: (333, 413)
# Object ID: 471, Center: (183, 402)
#
# 0: 640x640 4 cars, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 471, Center: (176, 411)
#
# 0: 640x640 1 car, 1 airplane, 43.5ms
# Speed: 4.0ms preprocess, 43.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 airplane, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 cars, 1 truck, 44.5ms
# Speed: 3.0ms preprocess, 44.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 cars, 1 truck, 43.9ms
# Speed: 3.0ms preprocess, 43.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 475, Center: (275, 268)
# Object ID: 472, Center: (308, 282)
#
# 0: 640x640 3 cars, 1 bus, 44.2ms
# Speed: 3.7ms preprocess, 44.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 476, Center: (333, 412)
# Object ID: 475, Center: (271, 272)
# Object ID: 472, Center: (302, 292)
#
# 0: 640x640 3 cars, 1 bus, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 475, Center: (267, 279)
# Object ID: 472, Center: (296, 303)
#
# 0: 640x640 4 cars, 1 bus, 43.7ms
# Speed: 3.0ms preprocess, 43.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 475, Center: (263, 286)
# Object ID: 472, Center: (289, 317)
#
# 0: 640x640 5 cars, 1 bus, 44.0ms
# Speed: 3.1ms preprocess, 44.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 475, Center: (258, 293)
# Object ID: 472, Center: (283, 334)
#
# 0: 640x640 5 cars, 1 bus, 43.5ms
# Speed: 3.5ms preprocess, 43.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 479, Center: (306, 309)
# Object ID: 475, Center: (252, 302)
# Object ID: 472, Center: (274, 351)
#
# 0: 640x640 5 cars, 1 bus, 44.5ms
# Speed: 3.0ms preprocess, 44.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 479, Center: (301, 322)
# Object ID: 475, Center: (246, 312)
# Object ID: 472, Center: (264, 372)
#
# 0: 640x640 4 cars, 1 bus, 1 truck, 43.5ms
# Speed: 5.0ms preprocess, 43.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 481, Center: (323, 273)
# Object ID: 479, Center: (297, 337)
# Object ID: 475, Center: (240, 323)
# Object ID: 472, Center: (253, 391)
#
# 0: 640x640 4 cars, 2 buss, 1 truck, 43.7ms
# Speed: 3.7ms preprocess, 43.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 481, Center: (319, 280)
# Object ID: 479, Center: (291, 353)
# Object ID: 475, Center: (232, 335)
# Object ID: 472, Center: (240, 406)
#
# 0: 640x640 4 cars, 1 bus, 2 trucks, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 482, Center: (271, 275)
# Object ID: 481, Center: (316, 290)
# Object ID: 479, Center: (284, 372)
# Object ID: 475, Center: (224, 348)
# Object ID: 472, Center: (226, 420)
#
# 0: 640x640 4 cars, 1 truck, 43.7ms
# Speed: 3.5ms preprocess, 43.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 482, Center: (265, 280)
# Object ID: 481, Center: (312, 302)
# Object ID: 479, Center: (277, 394)
# Object ID: 475, Center: (214, 362)
#
# 0: 640x640 4 cars, 1 truck, 43.5ms
# Speed: 3.0ms preprocess, 43.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 482, Center: (261, 288)
# Object ID: 481, Center: (309, 313)
# Object ID: 479, Center: (268, 412)
# Object ID: 475, Center: (204, 379)
#
# 0: 640x640 4 cars, 1 bus, 1 truck, 43.6ms
# Speed: 3.5ms preprocess, 43.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 482, Center: (255, 296)
# Object ID: 481, Center: (303, 327)
# Object ID: 479, Center: (258, 427)
# Object ID: 475, Center: (193, 398)
#
# 0: 640x640 4 cars, 1 truck, 43.5ms
# Speed: 4.0ms preprocess, 43.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 482, Center: (248, 306)
# Object ID: 481, Center: (297, 342)
# Object ID: 475, Center: (182, 411)
#
# 0: 640x640 3 cars, 2 trucks, 43.5ms
# Speed: 4.0ms preprocess, 43.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 485, Center: (289, 265)
# Object ID: 482, Center: (241, 317)
# Object ID: 481, Center: (291, 359)
# Object ID: 475, Center: (173, 423)
#
# 0: 640x640 2 cars, 1 truck, 43.6ms
# Speed: 4.0ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 485, Center: (284, 269)
# Object ID: 482, Center: (233, 329)
# Object ID: 481, Center: (283, 379)
#
# 0: 640x640 2 cars, 1 bus, 1 truck, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 485, Center: (277, 274)
# Object ID: 482, Center: (224, 343)
# Object ID: 481, Center: (275, 400)
#
# 0: 640x640 3 cars, 1 bus, 1 truck, 44.4ms
# Speed: 3.2ms preprocess, 44.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 485, Center: (271, 280)
# Object ID: 482, Center: (214, 358)
# Object ID: 481, Center: (265, 416)
#
# 0: 640x640 4 cars, 1 truck, 43.4ms
# Speed: 3.0ms preprocess, 43.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 485, Center: (264, 288)
# Object ID: 481, Center: (255, 430)
#
# 0: 640x640 3 cars, 2 trucks, 43.6ms
# Speed: 3.0ms preprocess, 43.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 486, Center: (185, 395)
# Object ID: 485, Center: (256, 298)
#
# 0: 640x640 3 cars, 1 truck, 45.0ms
# Speed: 3.0ms preprocess, 45.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 487, Center: (336, 351)
# Object ID: 486, Center: (177, 407)
# Object ID: 485, Center: (247, 308)
#
# 0: 640x640 3 cars, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 488, Center: (320, 265)
# Object ID: 487, Center: (333, 376)
# Object ID: 485, Center: (238, 319)
#
# 0: 640x640 3 cars, 44.2ms
# Speed: 2.0ms preprocess, 44.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 488, Center: (316, 271)
# Object ID: 487, Center: (328, 398)
# Object ID: 485, Center: (228, 331)
#
# 0: 640x640 3 cars, 1 truck, 43.5ms
# Speed: 3.5ms preprocess, 43.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 488, Center: (313, 277)
# Object ID: 485, Center: (217, 345)
#
# 0: 640x640 3 cars, 44.1ms
# Speed: 3.2ms preprocess, 44.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 488, Center: (309, 286)
# Object ID: 485, Center: (205, 361)
#
# 0: 640x640 2 cars, 1 truck, 45.1ms
# Speed: 3.0ms preprocess, 45.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 488, Center: (305, 298)
# Object ID: 485, Center: (193, 377)
#
# 0: 640x640 2 cars, 1 truck, 43.5ms
# Speed: 4.0ms preprocess, 43.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 488, Center: (300, 311)
# Object ID: 485, Center: (181, 396)
#
# 0: 640x640 3 cars, 1 truck, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Object ID: 488, Center: (294, 325)
# Object ID: 485, Center: (171, 409)

# %%
ht,wt = frame.shape[0:2]

# %%
ht,wt
# Out:
# (478, 848)

# %%
def region_of_interest(image,region_point):
    mask= np.zeros_like(image)
    cv2.fillPoly(mask,region_point, 255)
    masked_img=cv2.bitwise_and(image, mask)
    return masked_img
